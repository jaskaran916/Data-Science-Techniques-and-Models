# %% [markdown]
# <a href="https://www.kaggle.com/code/jaskarandhillon1609/basic-pandas-search-operations?scriptVersionId=210541138" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame({'sports': [21,34,56,78,97], 'studies': [32,24,63,13,44], 'music': [45,57,89,91,21]})

# %%
df.head(2)
# Out:
#    sports  studies  music
# 0      21       32     45
# 1      34       24     57

# %%
df.tail(3)
# Out:
#    sports  studies  music
# 2      56       63     89
# 3      78       13     91
# 4      97       44     21

# %%
list_1 = [24,23,25,36]
list_2 = [45,66,73,43,52]
list_1.extend(list_2)
print(list_1)
# Out:
# [24, 23, 25, 36, 45, 66, 73, 43, 52]

# %%
data = [2,3,4,5]
ser = pd.Series(data)
print(ser)
# Out:
# 0    2
# 1    3
# 2    4
# 3    5
# dtype: int64

# %%
df.to_numpy()
# Out:
# array([[21, 32, 45],
#        [34, 24, 57],
#        [56, 63, 89],
#        [78, 13, 91],
#        [97, 44, 21]])

# %%
df.to_string()
# Out:
# '   sports  studies  music\n0      21       32     45\n1      34       24     57\n2      56       63     89\n3      78       13     91\n4      97       44     21'

# %%
df.isnull()
# Out:
#    sports  studies  music
# 0   False    False  False
# 1   False    False  False
# 2   False    False  False
# 3   False    False  False
# 4   False    False  False

# %%
df.isna()
# Out:
#    sports  studies  music
# 0   False    False  False
# 1   False    False  False
# 2   False    False  False
# 3   False    False  False
# 4   False    False  False

# %%
df.astype(int)
# Out:
#    sports  studies  music
# 0      21       32     45
# 1      34       24     57
# 2      56       63     89
# 3      78       13     91
# 4      97       44     21
